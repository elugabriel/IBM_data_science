# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Elufidodo Gabriel**
# I am a data scientist

# %% [markdown]
# *I am interested in data science because because the world is generating billions of data every minute and i want tto be part of the people who will be able to get insight from the data and use the knowledge to make valuable contribution to the world*

# %% [markdown]
# ### The code below will show the result of simple mathematical expression

# %%
a = 35
b = 56

c = b**2
d = b*c

print("the result of b square is ", c , " and the product is ", d)
# Out:
# the result of b square is  3136  and the product is  175616

# %% [markdown]
# -  one
# -  two
#
# 1. a
# 2. b
# 3. c
#
#
# ![ibm.png](attachment:ibm.png)
